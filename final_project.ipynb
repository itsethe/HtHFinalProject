# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# %%
import csv
with open("Most_Streamed_Spotify_Songs_2024.csv", 'r') as file:
    df = csv.reader(file)

# %%
df = pd.read_csv('Most_Streamed_Spotify_Songs_2024.csv', encoding='latin1')


df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
df.head(10)
# Out:
#                         Track                                    Album Name  \
# 0         MILLION DOLLAR BABY                  Million Dollar Baby - Single
# 1                 Not Like Us                                   Not Like Us
# 2  i like the way you kiss me                    I like the way you kiss me
# 3                     Flowers                              Flowers - Single
# 4                     Houdini                                       Houdini
# 5                 Lovin On Me                                   Lovin On Me
# 6            Beautiful Things                              Beautiful Things
# 7                   Gata Only                                     Gata Only
# 8        Danza Kuduro - Cover  ýýýýýýýýýýýýýýýýýýýýý - ýýýýýýýýýýýýýýýýýý -
# 9  BAND4BAND (feat. Lil Baby)                    BAND4BAND (feat. Lil Baby)
#
#            Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity',
#        'Explicit Track'],
#       dtype='object')

# %%
top_spotify_songs = df.sort_values(by='Spotify Streams', ascending=False)
print(top_spotify_songs.head(10)[['Track', 'Spotify Streams']])
# Out:
#                            Track Spotify Streams
# 3157         Best Day Of My Life     999,525,686
# 137                      vampire     998,964,097
# 44         My Love Mine All Mine     997,702,304
# 785                      vampire     997,536,616
# 1179          Wake Up in the Sky     996,942,947
# 2395              Benjamins Deli         996,881
# 3508           I Was Never There     995,463,505
# 969          Piece Of Your Heart     995,452,298
# 1707                        Vete     991,885,224
# 4446  Feel So Close - Radio Edit     991,382,346

# %%
seaborn.barplot(top_spotify_songs, palette="deep")

plt.xlabel("Song")
plt.ylabel("Spotify Streams")
plt.title("Top 10 Most Streamed Spotify songs 2024")
plt.xticks(rotation=45)
plt.show()

# %%
spotify_data_sorted = df.sort_values(by='Spotify Streams', ascending=False)

# Get the top 10 songs
top_10 = spotify_data_sorted.head(10)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10['Track'], top_10['Spotify Streams'], color='skyblue')
plt.xlabel('Track')
plt.ylabel('Spotify Streams')
plt.title('Top 10 Most Streamed Spotify Songs')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
spotify_data_sorted = df.sort_values(by='Spotify Streams', ascending=False)

# Get the top 10 songs
top_10_artists_spotify = spotify_data_sorted.head(10)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10['Artist'], top_10['Spotify Streams'], color='skyblue')
plt.xlabel('Artist')
plt.ylabel('Spotify Streams')
plt.title('Top 10 Most Streamed Spotify Songs')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
tiktok_data_sorted = df.sort_values(by='TikTok Views', ascending=False)

# Get the top 10 songs
top_10_tiktok = tiktok_data_sorted.head(10)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10['Track'], top_10['TikTok Views'], color='skyblue')
plt.xlabel('Track')
plt.ylabel('TikTok Streams')
plt.title('Top 10 Most Streamed TIkTok Songs')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
tiktok_data_sorted = df.sort_values(by='TikTok Views', ascending=False)

# Get the top 10 songs
top_10_tiktok = tiktok_data_sorted.head(10)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10['Artist'], top_10['TikTok Views'], color='skyblue')
plt.xlabel('Artists')
plt.ylabel('TikTok Streams')
plt.title('Top 10 Most Streamed TIkTok Songs')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
youtube_data_sorted = df.sort_values(by='YouTube Views', ascending=False)

# Get the top 10 songs
top_10_artists_youtube = youtube_data_sorted.head(10)

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10['Track'], top_10['YouTube Views'], color='skyblue')
plt.xlabel('Track')
plt.ylabel('YouTube Streams')
plt.title('Top 10 Most Streamed YouTube Songs')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
